# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create url for query 

url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={weather_api_key}&q=lat,lon"
print(query_url)

city = ['lat', 'lon']

#lists to hold response info
lat = []
lon = []
max_temp = []
humidity = []
cloudy = []
wspeed = []
country = []
date = []

#Loop through the list of cities and perform a request for data on each
for city in cities:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudy.append(response['clouds']['all'])
        wspeed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        
cities
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=f6fdde5cb8d527a63ed5c816d534b1f6&q=lat,lon
# ['ushuaia',
#  'cape town',
#  'mataura',
#  'punta arenas',
#  'taoudenni',
#  'beidao',
#  'ilulissat',
#  'laguna',
#  'bredasdorp',
#  'hermanus',
#  'bereznik',
#  'longyearbyen',
#  'victor harbor',
#  'avarua',
#  'ibra',
#  'the valley',
#  'nanortalik',
#  'komsomolskiy',
#  'estevan',
#  'busselton',
#  'gat',
#  'yazoo city',
#  'taolanaro',
#  'rikitea',
#  'port hardy',
#  'vaini',
#  'daru',
#  'barentsburg',
#  'pevek',
#  'kapaa',
#  'batemans bay',
#  'kavaratti',
#  'talnakh',
#  'kalaleh',
#  'malavalli',
#  'college',
#  'bay roberts',
#  'albany',
#  'fort nelson',
#  'kruisfontein',
#  'ferrol',
#  'ambilobe',
#  'coihaique',
#  'tsihombe',
#  'ahipara',
#  'axim',
#  'jamestown',
#  'cam ranh',
#  'port alfred',
#  'tessalit',
#  'rocha',
#  'quatre cocos',
#  'arraial do cabo',
#  'roura',
#  'nikolskoye',
#  'mehamn',
#  'bambous virieux',
#  'grand gaube',
#  'sisophon',
#  'toliary',
#  'srednekolymsk',
#  'sembakung',
#  'yeppoon',
#  'avera',
#  'namibe',
#  'vestmannaeyjar',
#  'berdigestyakh',
#  'bluff',
#  'ken caryl',
#  'xai-xai',
#  'comodoro rivadavia',
#  'guerrero negro',
#  'takoradi',
#  'tasiilaq',
#  'hofn',
#  'sao paulo de olivenca',
#  'hasaki',
#  'upernavik',
#  'nador',
#  'mahebourg',
#  'nabire',
#  'saint-augustin',
#  'rio gallegos',
#  'luderitz',
#  'sao joao da barra',
#  'tuktoyaktuk',
#  'butaritari',
#  'maldonado',
#  'puerto ayora',
#  'chuy',
#  'tahoua',
#  'dikson',
#  'ponta do sol',
#  'tiksi',
#  'richards bay',
#  'karaul',
#  'saleaula',
#  'vargashi',
#  'kiama',
#  'broome',
#  'saint george',
#  'yellowknife',
#  'fairbanks',
#  'kaka',
#  'te anau',
#  'sola',
#  'alice springs',
#  'yerbogachen',
#  'norman wells',
#  'chokurdakh',
#  'new norfolk',
#  'ancud',
#  'breves',
#  'severo-kurilsk',
#  'georgetown',
#  'katsuura',
#  'mumbwa',
#  'kidal',
#  'edd',
#  'souillac',
#  'pangnirtung',
#  'cabedelo',
#  'hobart',
#  'amderma',
#  'temaraia',
#  'port elizabeth',
#  'henties bay',
#  'barranca',
#  'paamiut',
#  'faanui',
#  'thompson',
#  'tabialan',
#  'horqueta',
#  'hithadhoo',
#  'saskylakh',
#  'cherskiy',
#  'pantelho',
#  'xining',
#  'syracuse',
#  'qaanaaq',
#  'labuan',
#  'barrow',
#  'mount gambier',
#  'halalo',
#  'marcona',
#  'kutum',
#  'san quintin',
#  'mys shmidta',
#  'san patricio',
#  'sambava',
#  'bacolod',
#  'kodiak',
#  'erdenet',
#  'umm lajj',
#  'isabela',
#  'pacific grove',
#  'agirish',
#  'east london',
#  'nome',
#  'goure',
#  'victoria',
#  'seymchan',
#  'west plains',
#  'provideniya',
#  'anahuac',
#  'ayan',
#  'nautla',
#  'atuona',
#  'sozimskiy',
#  'omsukchan',
#  'kaitangata',
#  'taiyuan',
#  'hendek',
#  'porto walter',
#  'jinxiang',
#  'olinda',
#  'lebu',
#  'rudnogorsk',
#  'torbay',
#  'nevelsk',
#  'lanzhou',
#  'doctor pedro p. pena',
#  'vuktyl',
#  'cap malheureux',
#  'ostrovnoy',
#  'waki',
#  'keelung',
#  'wahran',
#  'brae',
#  'hilo',
#  'san jose',
#  'chongwe',
#  'castro',
#  'mar del plata',
#  'sechura',
#  'plettenberg bay',
#  'bereda',
#  'sangar',
#  'luanda',
#  'tumannyy',
#  'qaqortoq',
#  'bosaso',
#  'novoagansk',
#  'phnum penh',
#  'sayyan',
#  'rostaq',
#  'amapa',
#  'chimoio',
#  'narsaq',
#  'khatanga',
#  'illoqqortoormiut',
#  'vestmanna',
#  'coquimbo',
#  'kukushtan',
#  'carutapera',
#  'nesna',
#  'banmo',
#  'palmer',
#  'ranong',
#  'urumqi',
#  'isla mujeres',
#  'nylstroom',
#  'silleda',
#  'meulaboh',
#  'ribeira grande',
#  'virginia beach',
#  'geraldton',
#  'sentyabrskiy',
#  'mount isa',
#  'soyo',
#  'souris',
#  'affoltern',
#  'capreol',
#  'ouesso',
#  'hollister',
#  'olbia',
#  'twin falls',
#  'soto la marina',
#  'tual',
#  'leshukonskoye',
#  'chimbote',
#  'bengkulu',
#  'cidreira',
#  'puerto escondido',
#  'los llanos de aridane',
#  'kerman',
#  'touros',
#  'pires do rio',
#  'nizhnyaya omka',
#  'garowe',
#  'cabo san lucas',
#  'pisco',
#  'cortez',
#  'tuatapere',
#  'iki-burul',
#  'asosa',
#  'port shepstone',
#  'schmallenberg',
#  'chake chake',
#  'hambantota',
#  'general roca',
#  'belushya guba',
#  'mackay',
#  'shepsi',
#  'sabha',
#  'genhe',
#  'riyadh',
#  'flinders',
#  'nata',
#  'lushunkou',
#  'karabash',
#  'kudahuvadhoo',
#  'samusu',
#  'northam',
#  'inhambane',
#  'valparaiso',
#  'lasa',
#  'matagami',
#  'buraydah',
#  'sisimiut',
#  'berlevag',
#  'orda',
#  'faya',
#  'domoni',
#  'mazamari',
#  'oistins',
#  'panguna',
#  'chilca',
#  'bowling green',
#  'olafsvik',
#  'santa vitoria do palmar',
#  'hay river',
#  'temba',
#  'hihifo',
#  'kenora',
#  'padang',
#  'saint-philippe',
#  'najran',
#  'vaitape',
#  'jinchang',
#  'bullas',
#  'grand river south east',
#  'volokolamsk',
#  'turukhansk',
#  'sinnamary',
#  'kahului',
#  'teluk nibung',
#  'chihuahua',
#  'leh',
#  'bonavista',
#  'fuling',
#  'eucaliptus',
#  'saldanha',
#  'vila velha',
#  'pandan',
#  'palabuhanratu',
#  'arlit',
#  'chelyabinsk-70',
#  'cairns',
#  'caravelas',
#  'waipawa',
#  'rovaniemi',
#  'loandjili',
#  'craig',
#  'saint-leu',
#  'picton',
#  'oktyabrskiy',
#  'skalistyy',
#  'udachnyy',
#  'abu kamal',
#  'toktogul',
#  'babanusah',
#  'the pas',
#  'siddipet',
#  'zyryanka',
#  'cerro largo',
#  'lavrentiya',
#  'clyde river',
#  'beloha',
#  'warrnambool',
#  'las piedras',
#  'bell ville',
#  'tyukalinsk',
#  'farafangana',
#  'newport',
#  'poltavka',
#  'jertih',
#  'yulara',
#  'ucluelet',
#  'port moresby',
#  'soure',
#  'nizhneyansk',
#  'puerto carreno',
#  'mayo',
#  'lagoa',
#  'soledade',
#  'samarai',
#  'sorvag',
#  'sofiysk',
#  'airai',
#  'uwayl',
#  'burica',
#  'krasnoselkup',
#  'alyangula',
#  'ushtobe',
#  'jumla',
#  'sao filipe',
#  'leningradskiy',
#  'lompoc',
#  'bethel',
#  'iqaluit',
#  'raudeberg',
#  'gorontalo',
#  'cruzeiro do sul',
#  'lecce',
#  'labutta',
#  'tazovskiy',
#  'omutinskoye',
#  'sitka',
#  'devonport',
#  'chapais',
#  'husavik',
#  'qui nhon',
#  'colac',
#  'dunedin',
#  'fortuna',
#  'esperance',
#  'canon city',
#  'kulhudhuffushi',
#  'kincardine',
#  'belmonte',
#  'inirida',
#  'rawson',
#  'roma',
#  'kamaishi',
#  'hualmay',
#  'garissa',
#  'alta floresta',
#  'namatanai',
#  'mmathubudukwane',
#  'kaniama',
#  'nyimba',
#  'tateyama',
#  'kargil',
#  'perambalur',
#  'maine-soroa',
#  'seoul',
#  'sebeta',
#  'kot samaba',
#  'mabaruma',
#  'weiden',
#  'yemelyanovo',
#  'pereslavl-zalesskiy',
#  'gizo',
#  'juneau',
#  'sunrise manor',
#  'bac lieu',
#  'half moon bay',
#  'makakilo city',
#  'mandalgovi',
#  'trelew',
#  'kirakira',
#  'kopervik',
#  'sivas',
#  'koungou',
#  'lolua',
#  'helena',
#  'sao jose da coroa grande',
#  'vao',
#  'ngunguru',
#  'marystown',
#  'antsohihy',
#  'maceio',
#  'foumban',
#  'khromtau',
#  'jacmel',
#  'misawa',
#  'abnub',
#  'ongandjera',
#  'litovko',
#  'kismayo',
#  'galway',
#  'mangrol',
#  'yaroslavskiy',
#  'ust-kuyga',
#  'roald',
#  'sorong',
#  'cosala',
#  'fare',
#  'bilma',
#  'batagay-alyta',
#  'lugovoy',
#  'mocuba',
#  'raahe',
#  'robat karim',
#  'zharkent',
#  'manggar',
#  'quchan',
#  'uvat',
#  'evensk',
#  'matay',
#  'aksarayskiy',
#  'awjilah',
#  'mahabad',
#  'russell',
#  'maniitsoq',
#  'harlingen',
#  'bojnurd',
#  'ulaangom',
#  'conde',
#  'codrington',
#  'mpophomeni',
#  'belaya gora',
#  'bauchi',
#  'grand centre',
#  'cedar city',
#  'goderich',
#  'bathsheba',
#  'isiro',
#  'goulburn',
#  'astara',
#  'salt',
#  'port lincoln',
#  'ndele',
#  'sembabule',
#  'cigaras',
#  'payo',
#  'ukiah',
#  'rameswaram',
#  'aljezur',
#  'mareeba',
#  'del rio',
#  'arecibo',
#  'vanavara',
#  'port augusta',
#  'nantucket',
#  'bandarbeyla',
#  'mehran',
#  'zaraza',
#  'aswan',
#  'noyabrsk',
#  'tura',
#  'huarmey',
#  'turayf',
#  'bintulu',
#  'kaeo',
#  'calvinia',
#  'baykit',
#  'marzuq',
#  'ust-omchug',
#  'port blair',
#  'snezhnogorsk',
#  'lorengau',
#  'yaan',
#  'smithers',
#  'dingle',
#  'berezovyy',
#  'toora-khem',
#  'tall kayf',
#  'usman',
#  'erzurum',
#  'miranda de ebro',
#  'sumbe',
#  'sarh',
#  'effium',
#  'celestun',
#  'vila franca do campo',
#  'anju',
#  'ishigaki',
#  'pondicherry',
#  'grootfontein',
#  'khani',
#  'berezayka',
#  'karpogory',
#  'itoman',
#  'athabasca',
#  'bolungarvik',
#  'narasannapeta',
#  'dunmore town',
#  'teguldet',
#  'anito',
#  'requena',
#  'kamen-rybolov',
#  'aklavik',
#  'sao caetano de odivelas',
#  'plattsburgh',
#  'shimoda',
#  'wanning',
#  'khonuu',
#  'luganville',
#  'baruun-urt',
#  'peace river',
#  'alofi',
#  'oyama',
#  'bambanglipuro',
#  'cascais',
#  'hegra',
#  'eureka',
#  'rongcheng',
#  'mobaye',
#  'klaksvik',
#  'abdulino',
#  'svetlogorsk',
#  'san cristobal',
#  'natal',
#  'clinton',
#  'auki',
#  'ngukurr',
#  'tjome',
#  'port angeles',
#  'bull savanna',
#  'port jervis',
#  'port hawkesbury',
#  'bermejo',
#  'tombouctou',
#  'gebre guracha',
#  'kavieng',
#  'beira',
#  'rincon',
#  'ketchikan',
#  'sataua',
#  'bougouni',
#  'mazabuka',
#  'karamay',
#  'bemidji',
#  'huntsville',
#  'sakakah',
#  'filadelfia',
#  'mariental',
#  'carnarvon',
#  'aldan',
#  'diu',
#  'porto novo',
#  'taksimo',
#  'linfen',
#  'attawapiskat',
#  'nsanje',
#  'seka',
#  'sao francisco',
#  'piopio',
#  'pakxan',
#  'santa fe',
#  'nizhniy lomov',
#  'kendari',
#  'fredericton',
#  'gewane',
#  'hokitika',
#  'nelson bay',
#  'abashiri',
#  'cayenne',
#  'voh',
#  'houma',
#  'kangaatsiaq',
#  'aasiaat',
#  'kysyl-syr',
#  'sao raimundo das mangabeiras',
#  'sur',
#  'atarra',
#  'oxbow',
#  'rolim de moura',
#  'imbituba',
#  'tortoli',
#  'zhanaozen',
#  'jacareacanga',
#  'okha',
#  'jaltepec']

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a dataframe from cities, and corresponding data from api
weather_data = ({
    "City": cities,
    "Latitude": lat,
    "Longitude": lon,
    "Max_temp": max_temp,
    "Humidity": humidity, 
    "Cloudy": cloudy,
    "Date": date,
    "Country": country,
    "Wind" : wspeed
})
weather_data = pd.DataFrame(weather_data)
weather_data
# Out:
#              City  Latitude  Longitude  Max_temp  Humidity  Cloudy  \
# 0         ushuaia    16.664    74.5126    300.69        64      99
# 1       cape town    16.664    74.5126    300.69        64      99
# 2         mataura    16.664    74.5126    300.69        64      99
# 3    punta arenas    16.664    74.5126    300.69        64      99
# 4       taoudenni    16.664    74.5126    300.69        64      99
# ..            ...       ...        ...       ...       ...     ...
# 621       tortoli    16.664    74.5126    300.69        64      99
# 622     zhanaozen    16.664    74.5126    300.69        64      99
# 623  jacareacanga    16.664    74.5126    300.69        64      99
# 624          okha    16.664    74.5126    300.69        64      99
# 625      jaltepec    16.664    74.5126    300.69        64      99
#
#            Date Country  Wind
# 0    1628743577      IN  6.25
# 1    1628743577      IN  6.25
# 2    1628743578      IN  6.25
# 3    1628743578      IN  6.25
# 4    1628743577      IN  6.25
# ..          ...     ...   ...
# 621  1628743577      IN  6.25
# 622  1628743577      IN  6.25
# 623  1628743578      IN  6.25
# 624  1628743577      IN  6.25
# 625  1628743577      IN  6.25
#
# [626 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
